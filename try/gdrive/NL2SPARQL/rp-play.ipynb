# %%
from urllib.request import urlopen
import json
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df = pd.read_csv('drive/My Drive/train9-prep.csv')

# %%
df = df.set_index('id')

# %%
df.head(2)
# Out:
#    answertype  ...                                          purequery
# id             ...
# 99   resource  ...  SELECT DISTINCT ?uri WHERE { res:Salt_Lake_Cit...
# 98   resource  ...  SELECT DISTINCT ?uri WHERE { ?uri dct:subject ...
#
# [2 rows x 8 columns]

# %%
pd.options.display.max_colwidth = 150
df[df['onlydbo']==False].purequery
# Out:
# id
# 98                                                                            SELECT DISTINCT ?uri WHERE { ?uri dct:subject dbc:Assassins_of_Julius_Caesar }
# 84                                           SELECT ?uri WHERE { ?uri dct:subject dbc:Presidents_of_the_United_States . res:Vietnam_War dbo:commander ?uri }
# 81     SELECT DISTINCT ?uri WHERE { ?uri a <http://dbpedia.org/class/yago/WikicatStatesOfTheUnitedStates> ; <http://dbpedia.org/property/governor> <http:...
# 44                                           SELECT ?uri WHERE { ?uri dct:subject dbc:Countries_in_Europe ; dbo:governmentType dbr:Constitutional_monarchy }
# 210            SELECT DISTINCT ?uri WHERE { ?uri rdf:type yago:WikicatMonarchsOfTheUnitedKingdom ; dbo:spouse ?spouse . ?spouse dbo:birthPlace res:Germany }
# 199    SELECT DISTINCT ?uri WHERE { { ?uri rdf:type yago:ArgentineFilms } UNION { ?uri rdf:type dbo:Film { ?uri dbo:country res:Argentina } UNION { ?uri ...
# ...

# %%
df[df['hybrid']==True].purequery
# hybrid is useless
# Out:
# Series([], Name: purequery, dtype: object)

# %%
del df['hybrid']

# %%
from nltk.tokenize import word_tokenize
import nltk
from nltk.corpus import stopwords

# %%
search = df.iloc[0].question
search
# Out:
# 'What is the time zone of Salt Lake City?'

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
processedWords = []
words = nltk.word_tokenize(search)
sTwords = stopwords.words('english')

#Removing stopwords
for word in words:
    if word not in sTwords:
        processedWords.append(word)

tagged_words = nltk.pos_tag(processedWords)

# %%
tagged_words
# Out:
# [('What', 'WP'),
#  ('time', 'NN'),
#  ('zone', 'NN'),
#  ('Salt', 'NNP'),
#  ('Lake', 'NNP'),
#  ('City', 'NNP'),
#  ('?', '.')]

# %%
# T5

# %%
! pip install simpletransformers

# %%
len(df)
# Out:
# 150

# %%
df.head(1)
# Out:
#    answertype  ...                                                                                      purequery
# id             ...
# 99   resource  ...  SELECT DISTINCT ?uri WHERE { res:Salt_Lake_City <http://dbpedia.org/ontology/timeZone> ?uri }
#
# [1 rows x 7 columns]

# %%
import logging
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in _dep_map(self)
#    3015         try:
# -> 3016             return self.__dep_map
#    3017         except AttributeError:
#
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in __getattr__(self, attr)
#    2812         if attr.startswith('_'):
# -> 2813             raise AttributeError(attr)
#    2814         return getattr(self._provider, attr)
#
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pkg_resources/__init__.py in _parsed_pkg_info(self)
#    3006         try:
# -> 3007             return self._pkg_info
#    3008         except AttributeError:
#
# ...
