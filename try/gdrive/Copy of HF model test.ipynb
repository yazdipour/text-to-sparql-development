# %%
# !pip install git+https://github.com/google-research/text-to-text-transfer-transformer.git
# Out:
# Collecting git+https://github.com/google-research/text-to-text-transfer-transformer.git
#   Cloning https://github.com/google-research/text-to-text-transfer-transformer.git to /tmp/pip-req-build-94880aol
#   Running command git clone -q https://github.com/google-research/text-to-text-transfer-transformer.git /tmp/pip-req-build-94880aol
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (0.12.0)
# Requirement already satisfied: babel in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (2.9.1)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (0.4.0)
# Collecting mesh-tensorflow[transformer]>=0.1.13
#   Downloading https://files.pythonhosted.org/packages/ce/10/37df0bc87ebf84e1414613176340e3aadc3697d2bd112bf63d3d4b1e848a/mesh_tensorflow-0.1.19-py3-none-any.whl (366kB)
#      |████████████████████████████████| 368kB 24.3MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (3.2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (1.1.5)
# Collecting rouge-score
#   Downloading https://files.pythonhosted.org/packages/1f/56/a81022436c08b9405a5247b71635394d44fe7e1dbedc4b28c740e09c2840/rouge_score-0.0.4-py2.py3-none-any.whl
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/7e/57/0c7ca4e31a126189dab99c19951910bd081dea5bbd25f24b77107750eae7/sacrebleu-1.5.1-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 9.2MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (1.4.1)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 49.8MB/s
# Collecting seqio
#   Downloading https://files.pythonhosted.org/packages/37/28/0a58b6eae1eaf11cac66969cb231826b8c4a9eef3479cc96ba085361af6d/seqio-0.0.5-py3-none-any.whl (249kB)
#      |████████████████████████████████| 256kB 43.2MB/s
# Requirement already satisfied: six>=1.14 in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (1.15.0)
# Collecting tensorflow-text
#   Downloading https://files.pythonhosted.org/packages/c0/ed/bbb51e9eccca0c2bfdf9df66e54cdff563b6f32daed9255da9b9a541368f/tensorflow_text-2.5.0-cp37-cp37m-manylinux1_x86_64.whl (4.3MB)
#      |████████████████████████████████| 4.3MB 47.1MB/s
# Collecting tfds-nightly
#   Downloading https://files.pythonhosted.org/packages/79/0a/8fecaa47d31848278f91fab40ec55cac7b52943fe127e7d00bd173c73a45/tfds_nightly-4.3.0.dev202105250106-py3-none-any.whl (3.9MB)
#      |████████████████████████████████| 3.9MB 49.4MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from t5==0.9.1) (1.8.1+cu101)
# Collecting transformers>=2.7.0
#   Downloading https://files.pythonhosted.org/packages/d5/43/cfe4ee779bbd6a678ac6a97c5a5cdeb03c35f9eaebbb9720b036680f9a2d/transformers-4.6.1-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.3MB 51.9MB/s
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel->t5==0.9.1) (2018.9)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from mesh-tensorflow[transformer]>=0.1.13->t5==0.9.1) (0.16.0)
# Requirement already satisfied: tensorflow-datasets; extra == "transformer" in /usr/local/lib/python3.7/dist-packages (from mesh-tensorflow[transformer]>=0.1.13->t5==0.9.1) (4.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->t5==0.9.1) (2.8.1)
# Collecting portalocker==2.0.0
#   Downloading https://files.pythonhosted.org/packages/89/a6/3814b7107e0788040870e8825eebf214d72166adf656ba7d4bf14759a06a/portalocker-2.0.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->t5==0.9.1) (1.0.1)
# Requirement already satisfied: tensorflow<2.6,>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text->t5==0.9.1) (2.5.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text->t5==0.9.1) (0.12.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (1.0.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (2.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (1.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (2.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (0.3.3)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (21.2.0)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (5.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (4.41.1)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from tfds-nightly->t5==0.9.1) (3.12.4)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 46.8MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=2.7.0->t5==0.9.1) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers>=2.7.0->t5==0.9.1) (4.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=2.7.0->t5==0.9.1) (20.9)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 40.4MB/s
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.7.0->t5==0.9.1) (2019.12.20)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets; extra == "transformer"->mesh-tensorflow[transformer]>=0.1.13->t5==0.9.1) (0.1.6)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (3.1.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (2.5.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.1.2)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.36.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (2.5.0.dev2021032900)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (2.5.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.2.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.4.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.12)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.34.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tfds-nightly->t5==0.9.1) (1.53.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly->t5==0.9.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly->t5==0.9.1) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly->t5==0.9.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly->t5==0.9.1) (3.0.4)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-resources; python_version < "3.9"->tfds-nightly->t5==0.9.1) (3.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.2->tfds-nightly->t5==0.9.1) (56.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=2.7.0->t5==0.9.1) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=2.7.0->t5==0.9.1) (7.1.2)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.30.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (4.2.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow-text->t5==0.9.1) (0.4.8)
# Building wheels for collected packages: t5
#   Building wheel for t5 (setup.py) ... done
#   Created wheel for t5: filename=t5-0.9.1-cp37-none-any.whl size=152187 sha256=704a6123b4640d506f5836ecbb69cefffb1bf9b242369529b5dfcdf2d9a95f6a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mj427_sp/wheels/57/7b/32/e05925d9426c15086d0e7c3795f6a2e30e738c3b3ec55d8e1d
# Successfully built t5
# Installing collected packages: mesh-tensorflow, rouge-score, portalocker, sacrebleu, sentencepiece, tensorflow-text, tfds-nightly, seqio, tokenizers, sacremoses, huggingface-hub, transformers, t5
# Successfully installed huggingface-hub-0.0.8 mesh-tensorflow-0.1.19 portalocker-2.0.0 rouge-score-0.0.4 sacrebleu-1.5.1 sacremoses-0.0.45 sentencepiece-0.1.95 seqio-0.0.5 t5-0.9.1 tensorflow-text-2.5.0 tfds-nightly-4.3.0.dev202105250106 tokenizers-0.10.3 transformers-4.6.1

# %%
import functools

import t5
import torch
import transformers

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

model = t5.models.HfPyTorchModel("t5-base", "/tmp/hft5/", device)

# Evaluate the pre-trained checkpoint, before further fine-tuning
model.eval(
    "glue_cola_v002",
    sequence_length={"inputs": 64, "targets": 4},
    batch_size=128,
)

# Run 1000 steps of fine-tuning
model.train(
    mixture_or_task_name="glue_cola_v002",
    steps=1000,
    save_steps=100,
    sequence_length={"inputs": 64, "targets": 4},
    split="train",
    batch_size=32,
    optimizer=functools.partial(transformers.AdamW, lr=1e-4),
)

# Evaluate after fine-tuning
model.eval(
    "glue_cola_v002",
    checkpoint_steps="all",
    sequence_length={"inputs": 64, "targets": 4},
    batch_size=128,
)

# Generate some predictions
inputs = [
    "cola sentence: This is a totally valid sentence.",
    "cola sentence: A doggy detail was walking famously.",
]
model.predict(
    inputs,
    sequence_length={"inputs": 32},
    batch_size=2,
    output_file="/tmp/hft5/example_predictions.txt",
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1199.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=891691430.0, style=ProgressStyle(descri…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c523940bfa7d> in <module>()
#      16     "glue_cola_v002",
#      17     sequence_length={"inputs": 64, "targets": 4},
# ---> 18     batch_size=128,
#      19 )
#      20
#
# /usr/local/lib/python3.7/dist-packages/t5/models/hf_model.py in eval(self, mixture_or_task_name, sequence_length, batch_size, checkpoint_steps, summary_dir, split, compute_sequence_length, **generate_kwargs)
#     452         split=split,
#     453         sequence_length=None if compute_sequence_length else sequence_length,
# --> 454         batch_size=batch_size)
#     455
#     456   def predict(
#
# /usr/local/lib/python3.7/dist-packages/t5/evaluation/eval_utils.py in run_eval(mixture_or_task_name, predict_or_score_fn, checkpoint_steps, dataset_fn, summary_dir, split, sequence_length, batch_size)
#     314   """
#     315
# --> 316   vocabulary = model_utils.get_vocabulary(mixture_or_task_name)
#     317
#     318   tasks = t5.data.get_subtasks(
#
# /usr/local/lib/python3.7/dist-packages/t5/models/utils.py in get_vocabulary(mixture_or_task_name)
#     112       logging.warning("Could not extract mixture/task name from gin config.")
#     113   if mixture_or_task_name:
# --> 114     provider = t5.data.get_mixture_or_task(mixture_or_task_name)
#     115     features = provider.output_features
#     116     if "inputs" in features and "targets" in features:
#
# /usr/local/lib/python3.7/dist-packages/seqio/dataset_providers.py in get_mixture_or_task(task_or_mixture_name)
#    1418   else:
#    1419     raise ValueError("No Task or Mixture found with name: %s" %
# -> 1420                      task_or_mixture_name)
#    1421
#    1422
#
# ValueError: No Task or Mixture found with name: glue_cola_v002

# %%
model.step
# Out:
# 0
