# %%
# !pip install git+https://github.com/google-research/text-to-text-transfer-transformer.git

# %%
import functools

import t5
import torch
import transformers

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

model = t5.models.HfPyTorchModel("t5-base", "/tmp/hft5/", device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-03ad6ad21b30> in <module>
#      10     device = torch.device("cpu")
#      11
# ---> 12 model = t5.models.HfPyTorchModel("t5-base", "/tmp/hft5/", device)
#
# ~/.local/lib/python3.8/site-packages/t5/models/hf_model.py in __init__(self, model_spec, model_dir, device)
#     208     self._device = device
#     209     if self._device.type == "cuda":
# --> 210       self._model.cuda()
#     211     self._step = 0
#     212     self.load_latest_checkpoint()
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#     489             Module: self
#     490         """
# --> 491         return self._apply(lambda t: t.cuda(device))
#     492
#     493     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     385     def _apply(self, fn):
#     386         for module in self.children():
# --> 387             module._apply(fn)
#     388
#     389         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     407                 # `with torch.no_grad():`
#     408                 with torch.no_grad():
# --> 409                     param_applied = fn(param)
#     410                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     411                 if should_use_set_data:
#
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py in <lambda>(t)
#     489             Module: self
#     490         """
# --> 491         return self._apply(lambda t: t.cuda(device))
#     492
#     493     def xpu(self: T, device: Optional[Union[int, device]] = None) -> T:
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 4.00 GiB total capacity; 2.33 GiB already allocated; 0 bytes free; 2.52 GiB reserved in total by PyTorch)

# %%
# Evaluate the pre-trained checkpoint, before further fine-tuning
model.eval(
    "glue_average",
    sequence_length={"inputs": 64, "targets": 4},
    batch_size=128,
)

# Run 1000 steps of fine-tuning
model.train(
    mixture_or_task_name="glue_cola_v002",
    steps=1000,
    save_steps=100,
    sequence_length={"inputs": 64, "targets": 4},
    split="train",
    batch_size=32,
    optimizer=functools.partial(transformers.AdamW, lr=1e-4),
)

# Evaluate after fine-tuning
model.eval(
    "glue_cola_v002",
    checkpoint_steps="all",
    sequence_length={"inputs": 64, "targets": 4},
    batch_size=128,
)

# Generate some predictions
inputs = [
    "cola sentence: This is a totally valid sentence.",
    "cola sentence: A doggy detail was walking famously.",
]
model.predict(
    inputs,
    sequence_length={"inputs": 32},
    batch_size=2,
    output_file="/tmp/hft5/example_predictions.txt",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f0a42a72f269> in <module>
#       1 # Evaluate the pre-trained checkpoint, before further fine-tuning
# ----> 2 model.eval(
#       3     "glue_average",
#       4     sequence_length={"inputs": 64, "targets": 4},
#       5     batch_size=128,
#
# ~/.local/lib/python3.8/site-packages/t5/models/hf_model.py in eval(self, mixture_or_task_name, sequence_length, batch_size, checkpoint_steps, summary_dir, split, compute_sequence_length, **generate_kwargs)
#     444     tf.io.gfile.makedirs(summary_dir)
#     445
# --> 446     run_eval(
#     447         mixture_or_task_name=mixture_or_task_name,
#     448         predict_or_score_fn=_predict_from_tasks,
#
# ~/.local/lib/python3.8/site-packages/t5/evaluation/eval_utils.py in run_eval(mixture_or_task_name, predict_or_score_fn, checkpoint_steps, dataset_fn, summary_dir, split, sequence_length, batch_size)
#     314   """
#     315
# --> 316   vocabulary = model_utils.get_vocabulary(mixture_or_task_name)
#     317
#     318   tasks = t5.data.get_subtasks(
#
# ~/.local/lib/python3.8/site-packages/t5/models/utils.py in get_vocabulary(mixture_or_task_name)
#     112       logging.warning("Could not extract mixture/task name from gin config.")
#     113   if mixture_or_task_name:
# --> 114     provider = t5.data.get_mixture_or_task(mixture_or_task_name)
#     115     features = provider.output_features
#     116     if "inputs" in features and "targets" in features:
#
# ~/.local/lib/python3.8/site-packages/seqio/dataset_providers.py in get_mixture_or_task(task_or_mixture_name)
#    1417     return TaskRegistry.get(task_or_mixture_name)
#    1418   else:
# -> 1419     raise ValueError("No Task or Mixture found with name: %s" %
#    1420                      task_or_mixture_name)
#    1421
#
# ValueError: No Task or Mixture found with name: glue_average
